# %% [markdown]
# ## Install Singularity

# %%
#   https://gist.github.com/jitvimol/41ea63cf5fa59810893a614878dfa018/edit   example code to run singularity
# !rm -rf /content/tutorial_singularity_in_colab/
# !git clone https://github.com/jitvimol/tutorial_singularity_in_colab.git
# !mv /content/tutorial_singularity_in_colab/* /content/sandbox_root/
# Out:
# Cloning into 'tutorial_singularity_in_colab'...
# remote: Enumerating objects: 7, done.
# remote: Counting objects: 100% (7/7), done.
# remote: Compressing objects: 100% (6/6), done.
# remote: Total 7 (delta 1), reused 7 (delta 1), pack-reused 0
# Unpacking objects: 100% (7/7), done.

# %%
# !wget https://github.com/OurGI-com/OurGI-src/blob/master/singularity/singularity_3.8.3_for_google_colab.deb?raw=true -O singularity_3.8.3_for_google_colab.deb
# !dpkg -i singularity_3.8.3_for_google_colab.deb
# !ln -s /usr/local/bin/singularity /usr/bin/sing
# !apt install nano squashfs-tools uidmap
# !mkdir -p /usr/local/var/singularity/mnt/session
# !singularity config fakeroot --add root
# Out:
# --2022-03-15 04:46:25--  https://github.com/OurGI-com/OurGI-src/blob/master/singularity/singularity_3.8.3_for_google_colab.deb?raw=true
# Resolving github.com (github.com)... 140.82.114.3
# Connecting to github.com (github.com)|140.82.114.3|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://github.com/OurGI-com/OurGI-src/raw/master/singularity/singularity_3.8.3_for_google_colab.deb [following]
# --2022-03-15 04:46:25--  https://github.com/OurGI-com/OurGI-src/raw/master/singularity/singularity_3.8.3_for_google_colab.deb
# Reusing existing connection to github.com:443.
# HTTP request sent, awaiting response... 302 Found
# Location: https://media.githubusercontent.com/media/OurGI-com/OurGI-src/master/singularity/singularity_3.8.3_for_google_colab.deb [following]
# --2022-03-15 04:46:25--  https://media.githubusercontent.com/media/OurGI-com/OurGI-src/master/singularity/singularity_3.8.3_for_google_colab.deb
# ...

# %%
from google.colab import drive
drive.mount('/content/drive' , force_remount=True)
# Out:
# Mounted at /content/drive

# %% [markdown]
# ## Gdown prebuilt tensorflow sandbox

# %%
# !pip install --no-cache --upgrade gdown
# Out:
# ...
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#     Preparing wheel metadata ... done
# ...
#   Created wheel for gdown: filename=gdown-4.4.0-py3-none-any.whl size=14774 sha256=ee50c8ae51372883030b93932b30f865da114a2d743a06092460aa424922de66
#   Stored in directory: /tmp/pip-ephem-wheel-cache-t8lxbtj3/wheels/fb/c3/0e/c4d8ff8bfcb0461afff199471449f642179b74968c15b7a69c
# Successfully built gdown
# ...
#   Attempting uninstall: gdown
#     Found existing installation: gdown 4.2.2
#     Uninstalling gdown-4.2.2:
#       Successfully uninstalled gdown-4.2.2
# ...

# %%
# !wget https://get2.cyou/tk6lD -O tensorflow_sandbox.zip
# !unzip tensorflow_sandbox.zip
# !rm tensorflow_sandbox.zip
# Out:
# Streaming output truncated to the last 5000 lines.
#   inflating: tensorflow_sandbox/usr/share/zoneinfo/posix/Africa/Abidjan
#   inflating: tensorflow_sandbox/usr/share/zoneinfo/posix/Africa/Accra
#     linking: tensorflow_sandbox/usr/share/zoneinfo/posix/Africa/Addis_Ababa  -> Nairobi
#   inflating: tensorflow_sandbox/usr/share/zoneinfo/posix/Africa/Algiers
#     linking: tensorflow_sandbox/usr/share/zoneinfo/posix/Africa/Asmara  -> Nairobi
#     linking: tensorflow_sandbox/usr/share/zoneinfo/posix/Africa/Asmera  -> Nairobi
#     linking: tensorflow_sandbox/usr/share/zoneinfo/posix/Africa/Bamako  -> Abidjan
#     linking: tensorflow_sandbox/usr/share/zoneinfo/posix/Africa/Bangui  -> Lagos
#     linking: tensorflow_sandbox/usr/share/zoneinfo/posix/Africa/Banjul  -> Abidjan
#   inflating: tensorflow_sandbox/usr/share/zoneinfo/posix/Africa/Bissau
#     linking: tensorflow_sandbox/usr/share/zoneinfo/posix/Africa/Blantyre  -> Maputo
# ...

# %% [markdown]
# ## Run tensorflow sandbox with Singularity, check for GPU access, and Export sif file

# %% [markdown]
# ### Check for GPUs
# Run python on Singularity shell and execute the following commands
# ```
# import tensorflow as tf
# tf.config.list_physical_devices('GPU')
# ```
# Feel freee to install additional depedencies in the sandbox

# %%
# !mkdir sandbox_root

# %%
# !mv /keras_example.py /content/sandbox_root/keras_example.py

# %%
# !singularity shell --fakeroot --writable -B /content/sandbox_root:/root --writable tensorflow_sandbox/
# Out:
# ERROR: ld.so: object '/usr/lib/x86_64-linux-gnu/libtcmalloc.so.4' from LD_PRELOAD cannot be preloaded (cannot open shared object file): ignored.
# bash: cannot set terminal process group (73): Inappropriate ioctl for device
# bash: no job control in this shell
# Singularity> ls
# ERROR: ld.so: object '/usr/lib/x86_64-linux-gnu/libtcmalloc.so.4' from LD_PRELOAD cannot be preloaded (cannot open shared object file): ignored.
# Singularity>
#
# Singularity>
# Singularity>
#
# Singularity> exit

# %% [markdown]
# ### Export sandbox to `*.sif` file to run on ThaiSC

# %%
# !sing build newsif.sif tensorflow_sandbox/
# Out:
# INFO:    Starting build...
# INFO:    Creating SIF file...

# %%
from google.colab import files
files.download('newsif.sif')

# %%
# !cp newsif.sif /content/drive/MyDrive/SuperAI/SuperAI-Pangpuriye/Week8-Image-Classification/singularity-sandbox/newsif.sif

# %% [markdown]
# ## (Optional) Build custom container image from Dockerhub and export to zip file
# Example usage: Build Pytorch CUDA image instead of tensorflow

# %%
# !wget https://github.com/OurGI-com/OurGI-src/blob/master/singularity/singularity_3.8.3_for_google_colab.deb?raw=true -O singularity_3.8.3_for_google_colab.deb
# !dpkg -i singularity_3.8.3_for_google_colab.deb
# !ln -s /usr/local/bin/singularity /usr/bin/sing
# !apt install nano squashfs-tools uidmap
# !mkdir -p /usr/local/var/singularity/mnt/session
# !singularity config fakeroot --add root

# %%
# %%capture
# !singularity build --sandbox tensorflow_sandbox/ docker://nvcr.io/nvidia/tensorflow:22.02-tf2-py3 # Can change docker path to other images on Dockerhub
# Out:
# Streaming output truncated to the last 5000 lines.
# …
# …
# …
# …
# …
# …
# …
# …
# …
# …
# …
# …
# …
# …
# …
# …
# …
# …
# …
# …
# …
# …
# …
# …
# …
# …
# …
# …
# …
# …
# …
# …
# …
# …
# …
# …
# …
# …
# …
# …
# …
# …
# …
# …
# …
# …
# …
# …
# …
# …
# …
# …
# …
# …
# …
# …
# …
# …
# …
# …
# …
# …
# …
# …
# …
# …
# …
# …
# …
# …
# …
# …
# …
# …
# …
# …
# …
# …
# …
# …
# …
# …
# …
# …
# …
# …
# …
# …
# …
# …
# …
# …
# …
# …
# …
# …
# …
# …
# …
# …
# …
# …
# …
# …
# …
# …
# …
# …
# …
# …
# …
# …
# …
# …
# …
# …
# …
# …
# …
# …
# …
# …
# …
# …
# …
# …
# …
# …
# …
# …
# …
# …
# …
# …
# …
# …
# …
# …
# …
# …
# …
# …
# …
# …
# …
# …
# …
# …
# …
# …
# …
# …
# …
# …
# …
# …
# …
# …
# …
# …
# …
# …
# …
# …
# …
# …
# …
# …
# …
# …
# …
# …
# …
# …
# …
# …
# …
# …
# …
# …
# …
# …
# …
# …
# …
# …
# …
# …
# …
# …
# …
# …
# …
# …
# …
# …
# …
# …
# …
# …
# …
# …
# …
# …
# …
# …
# …
# …
# …
# …
# …
# …
# …
# …
# …
# …
# …
# …
# …
# …
# …
# …
# …
# …
# …
# …
# …
# …
# …
# …
# …
# …
# …
# …
# …
# …
# ...

# %%
!7z a tensorflow_sandbox.zip tensorflow_sandbox/
# Out:
# 7-Zip [64] 16.02 : Copyright (c) 1999-2016 Igor Pavlov : 2016-05-21
# p7zip Version 16.02 (locale=en_US.UTF-8,Utf16=on,HugeFiles=on,64 bits,2 CPUs Intel(R) Xeon(R) CPU @ 2.30GHz (306F0),ASM,AES-NI)
#
# Scanning the drive:
# 15329 folders, 126633 files, 13073164099 bytes (13 GiB)
#
# Creating archive: tensorflow_sandbox.zip
#
# Items to compress: 141962
#
#   3% 2873 + tensorflow_sandbox/opt/nvidi . -desktop-glibc_2_11_3-x64/ncu

# %%
from google.colab import files
files.download('/content/tensorflow_sandbox.zip')
